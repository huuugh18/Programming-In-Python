# %%
import matplotlib.pyplot as plt
import numpy as np

data = np.arange(10)

plt.plot(data)

# %%
fig = plt.figure()

ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)

#when issuing a plotting command - matplotlib uses last figuer and subplot used
#k-- is a style option - black dashed line
plt.plot(np.random.randn(50).cumsum(), 'k--')

#can directly plot on the AxesSubplots objects
_ = ax1.hist(np.random.randn(100), bins=20, color='k', alpha=0.3)
ax2.scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30))

# %%
#creating a figure with a grid of subplots common task

fig, axes = plt.subplots(2,3)
axes

#axes can be indexed with a 2d array
axes[0,1]

#indicate subplots should have same x or y-axis using `sharex` and `sharey` respectively
# Out:
# <AxesSubplot:>

# %%
#colors markers and linestyles

# plot x vs y with green dashes
# ax.plot(x, y, 'g--')
#OR
# ax.plot(x, y, linestyle='--', color='g')

#can ad markers to highlight actual datapoints
from numpy.random import randn
plt.plot(randn(30).cumsum(), 'ko--')

# %%
# drawstyle option

data = np.random.randn(30).cumsum()
plt.plot(data, 'k--', label='Default')

# %%
plt.plot(data, 'k-', drawstyle='steps-post', label='Steps-post')

# %%
# setting title, axis labels, and ticklabels

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ticks = ax.set_xticks([0, 250, 500, 750, 1000])
label = ax.set_xticklabels(['one', 'two', 'three', 'four', 'five'], rotation=30, fontsize='small')
ax.set_title('Some Title')
ax.set_xlabel('Stages')
ax.plot(np.random.randn(1000).cumsum())

# %% [markdown]
# ## Plotting with Pandas and Seaborn
#
# Matplot lib fairly low level
# In pandas there are multiple columns of data along with rows and column labels
# Seaborn is a stats graphical library - simplifies creating many common visualization types
#
# ## Line Plots

# %%
import pandas as pd 

#series objects index passed for plotting x-axis - can disable using `use_index=False`
# x-axis ticks and limits can be adjusted with `xticks` and `xlim` options same with y-axis
s = pd.Series(np.random.randn(10).cumsum(), index = np.arange(0, 100, 10))
s.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Most of pandas plotting methods accept an optional `ax` paramater which can be a matplotlib subplot object
# Gives more felxible placement of subplots in a grid layout
#
# DataFrame's `plot` method plots each of its columns as a different line on same subplot creating a legend automatically

# %%
df = pd.DataFrame(np.random.randn(10, 4).cumsum(0), columns=['A', 'B', 'C', 'D'])
df.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# `plot` attribute contains a 'family' of methods for different plot types

# %% [markdown]
# # Bar plots
#
# `plot.bar()` and `plot.barh()` make vertical and horizontal bar plots
#
# In this case the Series or DF index will be used as the x(bar) or y(barh) ticks

# %%
fig,axes = plt.subplots(2,1)

data = pd.Series(np.random.rand(16), index=list('abcdefghijklmnop'))

data.plot.bar(ax=axes[0], color='k', alpha=0.7)
data.plot.barh(ax=axes[1], color='k', alpha=0.7)
# Out:
# <AxesSubplot:>

# %% [markdown]
# With a DF bar plots group the values in each row together in a group of bars side by side for each value

# %%
df = pd.DataFrame(np.random.rand(6, 4), index=['one', 'two', 'three', 'four', 'five', 'six'], columns=pd.Index(['A', 'B', 'C', 'D'], name='Genus'))
df.head(), df.plot.bar()
# Out:
# (Genus         A         B         C         D
#  one    0.078573  0.834063  0.953430  0.183786
#  two    0.397133  0.214639  0.026724  0.352118
#  three  0.073526  0.329230  0.515991  0.559337
#  four   0.835767  0.525469  0.610787  0.951125
#  five   0.001844  0.614548  0.945213  0.264148,
#  <AxesSubplot:>)

# %%
#stacked bar plots using `stacked=True`
df.plot.barh(stacked=True, alpha=0.5)
# Out:
# <AxesSubplot:>
