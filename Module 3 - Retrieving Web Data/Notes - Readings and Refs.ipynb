# %% [markdown]
# ## 3.3 Reading and Resources
#
# The Essential reading for this topic is:
# [McKinney, W. Python for Data Analysis. (Boston: O'Reilly, 2017) 2nd edition. pp.181-185.] (https://onlinelibrary.london.ac.uk/)
#
# Useful reference material can be found at:
#
# - [Python 'http protocol client', Internet protocols and support](https://docs.python.org/3/library/http.client.html)
# - [Python 'Simple HTML and XHTML parser' ](https://docs.python.org/3/library/html.parser.html)
# - [Pyquery 'A jquery-like library for Python' ](https://pythonhosted.org/pyquery/)
# - [Requests: HTTP for Humans](https://requests.readthedocs.io/en/master)

# %% [markdown]
# ## JSON DATA
#
# very nearly python code - exception is value `null`
# library `json` built into python
#
# `json.loads` => convert json string to python form
#
# `json.dumps` => convert python object back to json
#
# **Converting to a dataframe**
# Can pass a list of dicts (previously json objects) to DF constructor and select sub-set of the data fields
#
# `pandas.read_json` can automatically convert JSON datasets in a specific arrangement to Series or DF
# Default option assume that each object in JSON array is a row in the table
# Example: `data = pd.read_json('examples/example.json')`
#
# `data.to_json()` export pandas to json

# %%
import json
import pandas as pd

obj = """ 
{"name": "Wes", 
"places_lived": ["United States", "Spain", "Germany"], 
"pet": null, 
"siblings": [{"name": "Scott", "age": 30, "pets": ["Zeus", "Zuko"]}, 
            {"name": "Katie", "age": 38, "pets": ["Sixes", "Stache", "Cisco"]}] 
} 
"""

result = json.loads(obj)
asjson = json.dumps(result)

#dataframe

siblings = pd.DataFrame(result['siblings'], columns=['name', 'age'])
siblings
# Out:
#     name  age
# 0  Scott   30
# 1  Katie   38

# %% [markdown]
# ## Web Scraping
#
# ### Pandas `read_html`
# built in function which uses libraries 'lxml' and 'BeautifulSoup' to auto parse tables out of HMTL files as DF objects

# %%
tables = pd.read_html('data/fdic_failed_bank_list.html')
len(tables)

failures = tables[0]
failures.head()

# compute number of bank failures by year

close_timestamps = pd.to_datetime(failures['Closing Date'])
close_timestamps.dt.year.value_counts()
# Out:
# 2010    157
# 2009    140
# 2011     92
# 2012     51
# 2008     25
# 2013     24
# 2014     18
# 2002     11
# 2015      8
# 2016      5
# 2004      4
# 2001      4
# 2007      3
# 2003      3
# 2000      2
# Name: Closing Date, dtype: int64

# %% [markdown]
# ### Parsing XML with lxml.objectify

# %%
from lxml import objectify

path= 'data/Performance_MNR.xml'
parsed = objectify.parse(open(path))
root = parsed.getroot()

data = []

skip_fields=['PARENT_SEQ', 'INDICATOR_SEQ', 'DESIRED_CHANGE', 'DECIMAL_PLACES']

for elt in root.INDICATOR:
    el_data={}
    for child in elt.getchildren():
        if child.tag in skip_fields:
            continue
        el_data[child.tag] = child.pyval
    data.append(el_data)
    
# convert into a dataframe
perf = pd.DataFrame(data)

perf.head()
# Out:
#             AGENCY_NAME                        INDICATOR_NAME  \
# 0  Metro-North Railroad  On-Time Performance (West of Hudson)
# 1  Metro-North Railroad  On-Time Performance (West of Hudson)
# 2  Metro-North Railroad  On-Time Performance (West of Hudson)
# 3  Metro-North Railroad  On-Time Performance (West of Hudson)
# 4  Metro-North Railroad  On-Time Performance (West of Hudson)
#
#                                          DESCRIPTION  PERIOD_YEAR  \
# 0  Percent of commuter trains that arrive at thei...         2008
# 1  Percent of commuter trains that arrive at thei...         2008
# 2  Percent of commuter trains that arrive at thei...         2008
# 3  Percent of commuter trains that arrive at thei...         2008
# 4  Percent of commuter trains that arrive at thei...         2008
#
#    PERIOD_MONTH            CATEGORY FREQUENCY INDICATOR_UNIT YTD_TARGET  \
# 0             1  Service Indicators         M              %         95
# 1             2  Service Indicators         M              %         95
# 2             3  Service Indicators         M              %         95
# 3             4  Service Indicators         M              %         95
# 4             5  Service Indicators         M              %         95
#
#   YTD_ACTUAL MONTHLY_TARGET MONTHLY_ACTUAL
# 0       96.9             95           96.9
# 1         96             95             95
# 2       96.3             95           96.9
# 3       96.8             95           98.3
# 4       96.6             95           95.8

# %%
XML data can get much more complicated  
each tag can have metadata too

Example:

# %%
from io import StringIO
tag = "<a href='http://www.google.com'>Google</a>"
root = objectify.parse(StringIO(tag)).getroot()

# now can access any of the fields like href in the tag or the link text
root

print(root.get('href'), root.text)
# Out:
# http://www.google.com Google

# %% [markdown]
# ## `http.client ` -- HTTP protocol client
#
# ### [examples](https://docs.python.org/3/library/http.client.html#examples)

# %%
import http.client
conn = http.client.HTTPSConnection('www.python.org')
conn.request('GET', '/')
r1 = conn.getresponse()
print(r1.status, r1.reason)

# return entire content
data1 = r1.read()
# Out:
# 200 OK

# %%
#read into chunks

conn.request('GET', '/')
r1 = conn.getresponse()
while chunk := r1.read(200):
        repr(chunk)

# %% [markdown]
# ## `html.parser` -- Simple HTML and XHTML parser
#
#
# ### [examples](https://docs.python.org/3/library/html.parser.html#examples)

# %%
from html.parser import HTMLParser

class MyHTMLParser(HTMLParser):
    def handle_starttag(self, tag, attrs):
        print("Encountered a start tag:", tag)

    def handle_endtag(self, tag):
        print("Encountered an end tag :", tag)

    def handle_data(self, data):
        print("Encountered some data  :", data)

parser = MyHTMLParser()
parser.feed('<html><head><title>Test</title></head>'
            '<body><h1>Parse me!</h1></body></html>')
# Out:
# Encountered a start tag: html
# Encountered a start tag: head
# Encountered a start tag: title
# Encountered some data  : Test
# Encountered an end tag : title
# Encountered an end tag : head
# Encountered a start tag: body
# Encountered a start tag: h1
# Encountered some data  : Parse me!
# Encountered an end tag : h1
# Encountered an end tag : body
# Encountered an end tag : html

# %% [markdown]
# ## pyquery: a jquery like library for python
#
# ### [quickstart docs](https://pythonhosted.org/pyquery/)

# %% [markdown]
# ## Requests: HTTP for Humans
#
# simple HTTP library for python
#
# ### [requests quickstart docs](https://docs.python-requests.org/en/latest/user/quickstart/)

# %%
import requests
r = requests.get('https://api.github.com/events')
r.status_code
r.json()
# Out:
# [{'id': '16196834118',
#   'type': 'CreateEvent',
#   'actor': {'id': 78611625,
#    'login': 'BaeTheDreamBoat',
#    'display_login': 'BaeTheDreamBoat',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/BaeTheDreamBoat',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/78611625?'},
#   'repo': {'id': 364302571,
#    'name': 'BaeTheDreamBoat/School-particle-simulation',
#    'url': 'https://api.github.com/repos/BaeTheDreamBoat/School-particle-simulation'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': 'Version controll for the WIP School disease/virus spread simulation',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-05-04T15:30:33Z'},
#  {'id': '16196834110',
#   'type': 'PushEvent',
#   'actor': {'id': 80655633,
#    'login': 'CzY0913',
#    'display_login': 'CzY0913',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/CzY0913',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/80655633?'},
#   'repo': {'id': 357202405,
#    'name': 'CzY0913/AutoSyncScript',
#    'url': 'https://api.github.com/repos/CzY0913/AutoSyncScript'},
#   'payload': {'push_id': 7040328703,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/lxk0301',
#    'head': '37827fa5ca56622ef74499f08a16c7efb60ccd93',
#    'before': 'dc8b75ab22986e5b3638964c563dd08b9b083256',
#    'commits': [{'sha': '37827fa5ca56622ef74499f08a16c7efb60ccd93',
#      'author': {'email': '69370516+ElsaKing@users.noreply.github.com',
#       'name': 'ElsaKing'},
#      'message': 'Update z_mother_jump.js',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/CzY0913/AutoSyncScript/commits/37827fa5ca56622ef74499f08a16c7efb60ccd93'}]},
#   'public': True,
#   'created_at': '2021-05-04T15:30:33Z'},
#  {'id': '16196834124',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 83650632,
#    'login': 'MuxauD',
#    'display_login': 'MuxauD',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MuxauD',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/83650632?'},
#   'repo': {'id': 364257407,
#    'name': 'MuxauD/homepage',
#    'url': 'https://api.github.com/repos/MuxauD/homepage'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/MuxauD/homepage/issues/4',
#     'repository_url': 'https://api.github.com/repos/MuxauD/homepage',
#     'labels_url': 'https://api.github.com/repos/MuxauD/homepage/issues/4/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/MuxauD/homepage/issues/4/comments',
#     'events_url': 'https://api.github.com/repos/MuxauD/homepage/issues/4/events',
#     'html_url': 'https://github.com/MuxauD/homepage/issues/4',
#     'id': 875472525,
#     'node_id': 'MDU6SXNzdWU4NzU0NzI1MjU=',
#     'number': 4,
#     'title': 'Скласти інтро',
#     'user': {'login': 'MuxauD',
#      'id': 83650632,
#      'node_id': 'MDQ6VXNlcjgzNjUwNjMy',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/83650632?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/MuxauD',
#      'html_url': 'https://github.com/MuxauD',
#      'followers_url': 'https://api.github.com/users/MuxauD/followers',
#      'following_url': 'https://api.github.com/users/MuxauD/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/MuxauD/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/MuxauD/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/MuxauD/subscriptions',
#      'organizations_url': 'https://api.github.com/users/MuxauD/orgs',
#      'repos_url': 'https://api.github.com/users/MuxauD/repos',
#      'events_url': 'https://api.github.com/users/MuxauD/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/MuxauD/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 2971426132,
#       'node_id': 'MDU6TGFiZWwyOTcxNDI2MTMy',
#       'url': 'https://api.github.com/repos/MuxauD/homepage/labels/help%20wanted',
#       'name': 'help wanted',
#       'color': '008672',
#       'default': True,
#       'description': 'Extra attention is needed'}],
#     'state': 'closed',
#     'locked': False,
#     'assignee': {'login': 'colaboratorMuxu',
#      'id': 83651658,
#      'node_id': 'MDQ6VXNlcjgzNjUxNjU4',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/83651658?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/colaboratorMuxu',
#      'html_url': 'https://github.com/colaboratorMuxu',
#      'followers_url': 'https://api.github.com/users/colaboratorMuxu/followers',
#      'following_url': 'https://api.github.com/users/colaboratorMuxu/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/colaboratorMuxu/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/colaboratorMuxu/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/colaboratorMuxu/subscriptions',
#      'organizations_url': 'https://api.github.com/users/colaboratorMuxu/orgs',
#      'repos_url': 'https://api.github.com/users/colaboratorMuxu/repos',
#      'events_url': 'https://api.github.com/users/colaboratorMuxu/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/colaboratorMuxu/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'assignees': [{'login': 'colaboratorMuxu',
#       'id': 83651658,
#       'node_id': 'MDQ6VXNlcjgzNjUxNjU4',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/83651658?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/colaboratorMuxu',
#       'html_url': 'https://github.com/colaboratorMuxu',
#       'followers_url': 'https://api.github.com/users/colaboratorMuxu/followers',
#       'following_url': 'https://api.github.com/users/colaboratorMuxu/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/colaboratorMuxu/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/colaboratorMuxu/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/colaboratorMuxu/subscriptions',
#       'organizations_url': 'https://api.github.com/users/colaboratorMuxu/orgs',
#       'repos_url': 'https://api.github.com/users/colaboratorMuxu/repos',
#       'events_url': 'https://api.github.com/users/colaboratorMuxu/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/colaboratorMuxu/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'milestone': {'url': 'https://api.github.com/repos/MuxauD/homepage/milestones/1',
#      'html_url': 'https://github.com/MuxauD/homepage/milestone/1',
#      'labels_url': 'https://api.github.com/repos/MuxauD/homepage/milestones/1/labels',
#      'id': 6726026,
#      'node_id': 'MDk6TWlsZXN0b25lNjcyNjAyNg==',
#      'number': 1,
#      'title': 'Researching and planning',
#      'description': 'Obtain required information',
#      'creator': {'login': 'MuxauD',
#       'id': 83650632,
#       'node_id': 'MDQ6VXNlcjgzNjUwNjMy',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/83650632?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/MuxauD',
#       'html_url': 'https://github.com/MuxauD',
#       'followers_url': 'https://api.github.com/users/MuxauD/followers',
#       'following_url': 'https://api.github.com/users/MuxauD/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/MuxauD/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/MuxauD/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/MuxauD/subscriptions',
#       'organizations_url': 'https://api.github.com/users/MuxauD/orgs',
#       'repos_url': 'https://api.github.com/users/MuxauD/repos',
#       'events_url': 'https://api.github.com/users/MuxauD/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/MuxauD/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'open_issues': 3,
#      'closed_issues': 1,
#      'state': 'open',
#      'created_at': '2021-05-04T13:40:59Z',
#      'updated_at': '2021-05-04T15:30:33Z',
#      'due_on': '2021-05-04T07:00:00Z',
#      'closed_at': None},
#     'comments': 1,
#     'created_at': '2021-05-04T13:38:55Z',
#     'updated_at': '2021-05-04T15:30:33Z',
#     'closed_at': '2021-05-04T15:30:33Z',
#     'author_association': 'OWNER',
#     'active_lock_reason': None,
#     'body': 'Скласти інтро (вступ), де в 2-4 реченнях описати, що замовник робить, що подобається робити, що хочеться робити краще, що важливо робити, тощо.',
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/MuxauD/homepage/issues/comments/832033030',
#     'html_url': 'https://github.com/MuxauD/homepage/issues/4#issuecomment-832033030',
#     'issue_url': 'https://api.github.com/repos/MuxauD/homepage/issues/4',
#     'id': 832033030,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDgzMjAzMzAzMA==',
#     'user': {'login': 'MuxauD',
#      'id': 83650632,
#      'node_id': 'MDQ6VXNlcjgzNjUwNjMy',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/83650632?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/MuxauD',
#      'html_url': 'https://github.com/MuxauD',
#      'followers_url': 'https://api.github.com/users/MuxauD/followers',
#      'following_url': 'https://api.github.com/users/MuxauD/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/MuxauD/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/MuxauD/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/MuxauD/subscriptions',
#      'organizations_url': 'https://api.github.com/users/MuxauD/orgs',
#      'repos_url': 'https://api.github.com/users/MuxauD/repos',
#      'events_url': 'https://api.github.com/users/MuxauD/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/MuxauD/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2021-05-04T15:30:33Z',
#     'updated_at': '2021-05-04T15:30:33Z',
#     'author_association': 'OWNER',
#     'body': 'Good :)',
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2021-05-04T15:30:33Z'},
#  {'id': '16196834117',
#   'type': 'PushEvent',
#   'actor': {'id': 20560316,
#    'login': 'hisliweikang',
#    'display_login': 'hisliweikang',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hisliweikang',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/20560316?'},
#   'repo': {'id': 364250775,
#    'name': 'hisliweikang/hisliweikang.github.io',
#    'url': 'https://api.github.com/repos/hisliweikang/hisliweikang.github.io'},
#   'payload': {'push_id': 7040328711,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '58bea7303417f1f2e2f4837c4807bddf546b6eb0',
#    'before': '633a03795c9f4dcb5bcf40d39f8aa33eee8ac674',
#    'commits': [{'sha': '58bea7303417f1f2e2f4837c4807bddf546b6eb0',
#      'author': {'email': 'liweikang@foresee.com.cn', 'name': 'liweikang'},
#      'message': 'Site updated: 2021-05-04 23:30:27',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/hisliweikang/hisliweikang.github.io/commits/58bea7303417f1f2e2f4837c4807bddf546b6eb0'}]},
#   'public': True,
#   'created_at': '2021-05-04T15:30:33Z'},
#  {'id': '16196834121',
#   'type': 'CreateEvent',
#   'actor': {'id': 45625569,
#    'login': 'dkotsilo',
#    'display_login': 'dkotsilo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dkotsilo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45625569?'},
#   'repo': {'id': 335979864,
#    'name': 'dkotsilo/myshop',
#    'url': 'https://api.github.com/repos/dkotsilo/myshop'},
#   'payload': {'ref': 'deploy',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-05-04T15:30:33Z'},
#  {'id': '16196834112',
#   'type': 'WatchEvent',
#   'actor': {'id': 4404577,
#    'login': 'jguillermo',
#    'display_login': 'jguillermo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jguillermo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4404577?'},
#   'repo': {'id': 1712563,
#    'name': 'schmittjoh/metadata',
#    'url': 'https://api.github.com/repos/schmittjoh/metadata'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2021-05-04T15:30:33Z'},
#  {'id': '16196834111',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 65553080,
#    'login': 'codecov-commenter',
#    'display_login': 'codecov-commenter',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/codecov-commenter',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/65553080?'},
#   'repo': {'id': 189236569,
#    'name': 'nipreps/sdcflows',
#    'url': 'https://api.github.com/repos/nipreps/sdcflows'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/nipreps/sdcflows/issues/199',
#     'repository_url': 'https://api.github.com/repos/nipreps/sdcflows',
#     'labels_url': 'https://api.github.com/repos/nipreps/sdcflows/issues/199/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/nipreps/sdcflows/issues/199/comments',
#     'events_url': 'https://api.github.com/repos/nipreps/sdcflows/issues/199/events',
#     'html_url': 'https://github.com/nipreps/sdcflows/pull/199',
#     'id': 875471659,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NjI5ODA3NTg5',
#     'number': 199,
#     'title': 'FIX: Revise generation of the displacements field from coefficients',
#     'user': {'login': 'oesteban',
#      'id': 598470,
#      'node_id': 'MDQ6VXNlcjU5ODQ3MA==',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/598470?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/oesteban',
#      'html_url': 'https://github.com/oesteban',
#      'followers_url': 'https://api.github.com/users/oesteban/followers',
#      'following_url': 'https://api.github.com/users/oesteban/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/oesteban/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/oesteban/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/oesteban/subscriptions',
#      'organizations_url': 'https://api.github.com/users/oesteban/orgs',
#      'repos_url': 'https://api.github.com/users/oesteban/repos',
#      'events_url': 'https://api.github.com/users/oesteban/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/oesteban/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 3,
#     'created_at': '2021-05-04T13:37:59Z',
#     'updated_at': '2021-05-04T15:30:33Z',
#     'closed_at': None,
#     'author_association': 'COLLABORATOR',
#     'active_lock_reason': None,
#     'pull_request': {'url': 'https://api.github.com/repos/nipreps/sdcflows/pulls/199',
#      'html_url': 'https://github.com/nipreps/sdcflows/pull/199',
#      'diff_url': 'https://github.com/nipreps/sdcflows/pull/199.diff',
#      'patch_url': 'https://github.com/nipreps/sdcflows/pull/199.patch'},
#     'body': 'Resolves: #198.',
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/nipreps/sdcflows/issues/comments/832033028',
#     'html_url': 'https://github.com/nipreps/sdcflows/pull/199#issuecomment-832033028',
#     'issue_url': 'https://api.github.com/repos/nipreps/sdcflows/issues/199',
#     'id': 832033028,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDgzMjAzMzAyOA==',
#     'user': {'login': 'codecov-commenter',
#      'id': 65553080,
#      'node_id': 'MDQ6VXNlcjY1NTUzMDgw',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/65553080?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/codecov-commenter',
#      'html_url': 'https://github.com/codecov-commenter',
#      'followers_url': 'https://api.github.com/users/codecov-commenter/followers',
#      'following_url': 'https://api.github.com/users/codecov-commenter/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/codecov-commenter/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/codecov-commenter/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/codecov-commenter/subscriptions',
#      'organizations_url': 'https://api.github.com/users/codecov-commenter/orgs',
#      'repos_url': 'https://api.github.com/users/codecov-commenter/repos',
#      'events_url': 'https://api.github.com/users/codecov-commenter/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/codecov-commenter/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2021-05-04T15:30:33Z',
#     'updated_at': '2021-05-04T15:30:33Z',
#     'author_association': 'NONE',
#     'body': "# [Codecov](https://codecov.io/gh/nipreps/sdcflows/pull/199?src=pr&el=h1&utm_medium=referral&utm_source=github&utm_content=comment&utm_campaign=pr+comments&utm_term=nipreps) Report\n> Merging [#199](https://codecov.io/gh/nipreps/sdcflows/pull/199?src=pr&el=desc&utm_medium=referral&utm_source=github&utm_content=comment&utm_campaign=pr+comments&utm_term=nipreps) (a519ddd) into [master](https://codecov.io/gh/nipreps/sdcflows/commit/da140517186351006e2b2225f68149c923d967a5?el=desc&utm_medium=referral&utm_source=github&utm_content=comment&utm_campaign=pr+comments&utm_term=nipreps) (da14051) will **decrease** coverage by `0.04%`.\n> The diff coverage is `92.30%`.\n\n[![Impacted file tree graph](https://codecov.io/gh/nipreps/sdcflows/pull/199/graphs/tree.svg?width=650&height=150&src=pr&token=V2CS5adHYk&utm_medium=referral&utm_source=github&utm_content=comment&utm_campaign=pr+comments&utm_term=nipreps)](https://codecov.io/gh/nipreps/sdcflows/pull/199?src=pr&el=tree&utm_medium=referral&utm_source=github&utm_content=comment&utm_campaign=pr+comments&utm_term=nipreps)\n\n```diff\n@@            Coverage Diff             @@\n##           master     #199      +/-   ##\n==========================================\n- Coverage   94.45%   94.40%   -0.05%     \n==========================================\n  Files          23       23              \n  Lines        1622     1627       +5     \n  Branches      188      189       +1     \n==========================================\n+ Hits         1532     1536       +4     \n  Misses         61       61              \n- Partials       29       30       +1     \n```\n\n| Flag | Coverage Δ | |\n|---|---|---|\n| travis | `89.66% <92.30%> (-0.03%)` | :arrow_down: |\n| unittests | `94.26% <92.30%> (-0.05%)` | :arrow_down: |\n\nFlags with carried forward coverage won't be shown. [Click here](https://docs.codecov.io/docs/carryforward-flags?utm_medium=referral&utm_source=github&utm_content=comment&utm_campaign=pr+comments&utm_term=nipreps#carryforward-flags-in-the-pull-request-comment) to find out more.\n\n| [Impacted Files](https://codecov.io/gh/nipreps/sdcflows/pull/199?src=pr&el=tree&utm_medium=referral&utm_source=github&utm_content=comment&utm_campaign=pr+comments&utm_term=nipreps) | Coverage Δ | |\n|---|---|---|\n| [sdcflows/interfaces/bspline.py](https://codecov.io/gh/nipreps/sdcflows/pull/199/diff?src=pr&el=tree&utm_medium=referral&utm_source=github&utm_content=comment&utm_campaign=pr+comments&utm_term=nipreps#diff-c2RjZmxvd3MvaW50ZXJmYWNlcy9ic3BsaW5lLnB5) | `92.22% <92.30%> (-0.24%)` | :arrow_down: |\n\n------\n\n[Continue to review full report at Codecov](https://codecov.io/gh/nipreps/sdcflows/pull/199?src=pr&el=continue&utm_medium=referral&utm_source=github&utm_content=comment&utm_campaign=pr+comments&utm_term=nipreps).\n> **Legend** - [Click here to learn more](https://docs.codecov.io/docs/codecov-delta?utm_medium=referral&utm_source=github&utm_content=comment&utm_campaign=pr+comments&utm_term=nipreps)\n> `Δ = absolute <relative> (impact)`, `ø = not affected`, `? = missing data`\n> Powered by [Codecov](https://codecov.io/gh/nipreps/sdcflows/pull/199?src=pr&el=footer&utm_medium=referral&utm_source=github&utm_content=comment&utm_campaign=pr+comments&utm_term=nipreps). Last update [da14051...a519ddd](https://codecov.io/gh/nipreps/sdcflows/pull/199?src=pr&el=lastupdated&utm_medium=referral&utm_source=github&utm_content=comment&utm_campaign=pr+comments&utm_term=nipreps). Read the [comment docs](https://docs.codecov.io/docs/pull-request-comments?utm_medium=referral&utm_source=github&utm_content=comment&utm_campaign=pr+comments&utm_term=nipreps).\n",
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2021-05-04T15:30:33Z',
#   'org': {'id': 48300745,
#    'login': 'nipreps',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/nipreps',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/48300745?'}},
#  {'id': '16196834100',
#   'type': 'PushEvent',
#   'actor': {'id': 5020626,
#    'login': 'elect86',
#    'display_login': 'elect86',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/elect86',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5020626?'},
#   'repo': {'id': 62797233,
#    'name': 'scenerygraphics/sciview',
#    'url': 'https://api.github.com/repos/scenerygraphics/sciview'},
#   'payload': {'push_id': 7040328684,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/gradleCatalog',
#    'head': '9422816ce4719de3efaebe00e50734220ee6dff1',
#    'before': 'd509856e68a1aefb9b07e5d3975f0f9e9bc08692',
#    'commits': [{'sha': '9422816ce4719de3efaebe00e50734220ee6dff1',
#      'author': {'email': 'elect86@gmail.com', 'name': 'Giuseppe Barbieri'},
#      'message': 'fixing pom',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/scenerygraphics/sciview/commits/9422816ce4719de3efaebe00e50734220ee6dff1'}]},
#   'public': True,
#   'created_at': '2021-05-04T15:30:33Z',
#   'org': {'id': 25817257,
#    'login': 'scenerygraphics',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/scenerygraphics',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25817257?'}},
#  {'id': '16196834102',
#   'type': 'CreateEvent',
#   'actor': {'id': 83601176,
#    'login': 'youman-cmd34',
#    'display_login': 'youman-cmd34',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/youman-cmd34',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/83601176?'},
#   'repo': {'id': 364302600,
#    'name': 'youman-cmd34/rrtarnrgrhrhrjjtjtjtfj',
#    'url': 'https://api.github.com/repos/youman-cmd34/rrtarnrgrhrhrjjtjtjtfj'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-05-04T15:30:33Z'},
#  {'id': '16196834096',
#   'type': 'CreateEvent',
#   'actor': {'id': 5375137,
#    'login': 'PureWeen',
#    'display_login': 'PureWeen',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PureWeen',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5375137?'},
#   'repo': {'id': 239026564,
#    'name': 'xamarin/app-xamarintv',
#    'url': 'https://api.github.com/repos/xamarin/app-xamarintv'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Xamarin.Forms app demonstrating the dual-screen device capability for neo and duo devices',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-05-04T15:30:33Z',
#   'org': {'id': 790012,
#    'login': 'xamarin',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/xamarin',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/790012?'}},
#  {'id': '16196834091',
#   'type': 'WatchEvent',
#   'actor': {'id': 7852959,
#    'login': 'hevertoncastro',
#    'display_login': 'hevertoncastro',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hevertoncastro',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7852959?'},
#   'repo': {'id': 151017833,
#    'name': 'dangvanthanh/vue-here-maps',
#    'url': 'https://api.github.com/repos/dangvanthanh/vue-here-maps'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2021-05-04T15:30:33Z'},
#  {'id': '16196834089',
#   'type': 'PushEvent',
#   'actor': {'id': 81601245,
#    'login': 'tonphuongoanh',
#    'display_login': 'tonphuongoanh',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tonphuongoanh',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/81601245?'},
#   'repo': {'id': 352838643,
#    'name': 'bunrealcua/Project',
#    'url': 'https://api.github.com/repos/bunrealcua/Project'},
#   'payload': {'push_id': 7040328691,
#    'size': 3,
#    'distinct_size': 3,
#    'ref': 'refs/heads/main',
#    'head': '7e684eb72e2a014df1608ba0734cafb9eddba2e1',
#    'before': '60a3346a49907ff5d93adadb65a052cf37638965',
#    'commits': [{'sha': '6b196b31fdd2032e4fb1208e947329093d0cba13',
#      'author': {'email': 'oanh.phuongton@gmail.com', 'name': 'tonphuongoanh'},
#      'message': 'EditStudent',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/bunrealcua/Project/commits/6b196b31fdd2032e4fb1208e947329093d0cba13'},
#     {'sha': '842b81a47bc9ed226c79f5a374e7d76fc80bcb33',
#      'author': {'email': 'oanh.phuongton@gmail.com', 'name': 'tonphuongoanh'},
#      'message': 'Update EditStudent.cpp',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/bunrealcua/Project/commits/842b81a47bc9ed226c79f5a374e7d76fc80bcb33'},
#     {'sha': '7e684eb72e2a014df1608ba0734cafb9eddba2e1',
#      'author': {'email': 'oanh.phuongton@gmail.com', 'name': 'tonphuongoanh'},
#      'message': "Merge branch 'main' of https://github.com/bunrealcua/Project into main",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/bunrealcua/Project/commits/7e684eb72e2a014df1608ba0734cafb9eddba2e1'}]},
#   'public': True,
#   'created_at': '2021-05-04T15:30:33Z'},
#  {'id': '16196834078',
#   'type': 'PushEvent',
#   'actor': {'id': 80542304,
#    'login': 'asyncfinkd',
#    'display_login': 'asyncfinkd',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/asyncfinkd',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/80542304?'},
#   'repo': {'id': 361238291,
#    'name': 'asyncfinkd/hello-world',
#    'url': 'https://api.github.com/repos/asyncfinkd/hello-world'},
#   'payload': {'push_id': 7040328682,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '5cae51ffd118abfc60df71c22eda6b6c94d164d6',
#    'before': 'f53bff6949ff21769c6fc09eb6d71da0d10ea73b',
#    'commits': [{'sha': '5cae51ffd118abfc60df71c22eda6b6c94d164d6',
#      'author': {'email': 'shamgoingzuck@gmail.com', 'name': 'Nika Shamiladze'},
#      'message': 'Create main.aiml',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/asyncfinkd/hello-world/commits/5cae51ffd118abfc60df71c22eda6b6c94d164d6'}]},
#   'public': True,
#   'created_at': '2021-05-04T15:30:33Z'},
#  {'id': '16196834084',
#   'type': 'DeleteEvent',
#   'actor': {'id': 19492671,
#    'login': 'rdkcmf-jenkins',
#    'display_login': 'rdkcmf-jenkins',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rdkcmf-jenkins',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19492671?'},
#   'repo': {'id': 194688203,
#    'name': 'rdkcmf/rdkb-notify_comp',
#    'url': 'https://api.github.com/repos/rdkcmf/rdkb-notify_comp'},
#   'payload': {'ref': 'nightly/20191106-rdk-dev',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-05-04T15:30:33Z',
#   'org': {'id': 10209720,
#    'login': 'rdkcmf',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/rdkcmf',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10209720?'}},
#  {'id': '16196834082',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 23324155,
#    'login': 'CodyJasonBennett',
#    'display_login': 'CodyJasonBennett',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/CodyJasonBennett',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23324155?'},
#   'repo': {'id': 295147585,
#    'name': 'pmndrs/website',
#    'url': 'https://api.github.com/repos/pmndrs/website'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/pmndrs/website/issues/71',
#     'repository_url': 'https://api.github.com/repos/pmndrs/website',
#     'labels_url': 'https://api.github.com/repos/pmndrs/website/issues/71/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/pmndrs/website/issues/71/comments',
#     'events_url': 'https://api.github.com/repos/pmndrs/website/issues/71/events',
#     'html_url': 'https://github.com/pmndrs/website/pull/71',
#     'id': 874700826,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NjI5MjAyMzEz',
#     'number': 71,
#     'title': 'fix wording for Link `href` hint',
#     'user': {'login': 'jhsu',
#      'id': 648,
#      'node_id': 'MDQ6VXNlcjY0OA==',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/648?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/jhsu',
#      'html_url': 'https://github.com/jhsu',
#      'followers_url': 'https://api.github.com/users/jhsu/followers',
#      'following_url': 'https://api.github.com/users/jhsu/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/jhsu/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/jhsu/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/jhsu/subscriptions',
#      'organizations_url': 'https://api.github.com/users/jhsu/orgs',
#      'repos_url': 'https://api.github.com/users/jhsu/repos',
#      'events_url': 'https://api.github.com/users/jhsu/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/jhsu/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 2,
#     'created_at': '2021-05-03T16:01:08Z',
#     'updated_at': '2021-05-04T15:30:33Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'pull_request': {'url': 'https://api.github.com/repos/pmndrs/website/pulls/71',
#      'html_url': 'https://github.com/pmndrs/website/pull/71',
#      'diff_url': 'https://github.com/pmndrs/website/pull/71.diff',
#      'patch_url': 'https://github.com/pmndrs/website/pull/71.patch'},
#     'body': '',
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/pmndrs/website/issues/comments/832033029',
#     'html_url': 'https://github.com/pmndrs/website/pull/71#issuecomment-832033029',
#     'issue_url': 'https://api.github.com/repos/pmndrs/website/issues/71',
#     'id': 832033029,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDgzMjAzMzAyOQ==',
#     'user': {'login': 'CodyJasonBennett',
#      'id': 23324155,
#      'node_id': 'MDQ6VXNlcjIzMzI0MTU1',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/23324155?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/CodyJasonBennett',
#      'html_url': 'https://github.com/CodyJasonBennett',
#      'followers_url': 'https://api.github.com/users/CodyJasonBennett/followers',
#      'following_url': 'https://api.github.com/users/CodyJasonBennett/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/CodyJasonBennett/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/CodyJasonBennett/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/CodyJasonBennett/subscriptions',
#      'organizations_url': 'https://api.github.com/users/CodyJasonBennett/orgs',
#      'repos_url': 'https://api.github.com/users/CodyJasonBennett/repos',
#      'events_url': 'https://api.github.com/users/CodyJasonBennett/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/CodyJasonBennett/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2021-05-04T15:30:33Z',
#     'updated_at': '2021-05-04T15:30:33Z',
#     'author_association': 'COLLABORATOR',
#     'body': 'Looks good.',
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2021-05-04T15:30:33Z',
#   'org': {'id': 45790596,
#    'login': 'pmndrs',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/pmndrs',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45790596?'}},
#  {'id': '16196834063',
#   'type': 'PushEvent',
#   'actor': {'id': 1592064,
#    'login': 'dancrossnyc',
#    'display_login': 'dancrossnyc',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dancrossnyc',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1592064?'},
#   'repo': {'id': 351529697,
#    'name': 'dancrossnyc/rstpwr',
#    'url': 'https://api.github.com/repos/dancrossnyc/rstpwr'},
#   'payload': {'push_id': 7040328683,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '5385bc33932f29fb4b170372b296a61209330f0f',
#    'before': 'd63fedda1ac2973b4a04bc09a2fba0b5e4551f33',
#    'commits': [{'sha': '5385bc33932f29fb4b170372b296a61209330f0f',
#      'author': {'email': 'cross@gajendra.net', 'name': 'Dan Cross'},
#      'message': 'Update to KiCad6.\n\nSigned-off-by: Dan Cross <cross@gajendra.net>',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/dancrossnyc/rstpwr/commits/5385bc33932f29fb4b170372b296a61209330f0f'}]},
#   'public': True,
#   'created_at': '2021-05-04T15:30:33Z'},
#  {'id': '16196833993',
#   'type': 'WatchEvent',
#   'actor': {'id': 4404577,
#    'login': 'jguillermo',
#    'display_login': 'jguillermo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jguillermo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4404577?'},
#   'repo': {'id': 66571229,
#    'name': 'http-interop/http-factory-guzzle',
#    'url': 'https://api.github.com/repos/http-interop/http-factory-guzzle'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2021-05-04T15:30:33Z',
#   'org': {'id': 21023081,
#    'login': 'http-interop',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/http-interop',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/21023081?'}},
#  {'id': '16196834071',
#   'type': 'WatchEvent',
#   'actor': {'id': 4404577,
#    'login': 'jguillermo',
#    'display_login': 'jguillermo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jguillermo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4404577?'},
#   'repo': {'id': 96365747,
#    'name': 'Jean85/pretty-package-versions',
#    'url': 'https://api.github.com/repos/Jean85/pretty-package-versions'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2021-05-04T15:30:33Z'},
#  {'id': '16196834075',
#   'type': 'WatchEvent',
#   'actor': {'id': 10471399,
#    'login': 'nkbai',
#    'display_login': 'nkbai',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nkbai',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10471399?'},
#   'repo': {'id': 197081291,
#    'name': 'hecrj/iced',
#    'url': 'https://api.github.com/repos/hecrj/iced'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2021-05-04T15:30:33Z'},
#  {'id': '16196834058',
#   'type': 'WatchEvent',
#   'actor': {'id': 26086394,
#    'login': 'Nklya',
#    'display_login': 'Nklya',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Nklya',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26086394?'},
#   'repo': {'id': 312422819,
#    'name': 'FUSAKLA/promruval',
#    'url': 'https://api.github.com/repos/FUSAKLA/promruval'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2021-05-04T15:30:33Z'},
#  {'id': '16196834056',
#   'type': 'PushEvent',
#   'actor': {'id': 16455121,
#    'login': 'TheWolek',
#    'display_login': 'TheWolek',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/TheWolek',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16455121?'},
#   'repo': {'id': 350763667,
#    'name': 'TheWolek/vueTemplate',
#    'url': 'https://api.github.com/repos/TheWolek/vueTemplate'},
#   'payload': {'push_id': 7040328674,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/bootstrap',
#    'head': 'b2f602a2d088fc2e17ce73f7827d06587bfceca0',
#    'before': 'c347cee3ccbae670740de39935f1b0d41850dc0c',
#    'commits': [{'sha': 'b2f602a2d088fc2e17ce73f7827d06587bfceca0',
#      'author': {'email': 'pawelm916@wp.pl', 'name': 'TheWolek'},
#      'message': 'no font-size clamp',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/TheWolek/vueTemplate/commits/b2f602a2d088fc2e17ce73f7827d06587bfceca0'}]},
#   'public': True,
#   'created_at': '2021-05-04T15:30:33Z'},
#  {'id': '16196834043',
#   'type': 'PushEvent',
#   'actor': {'id': 42967728,
#    'login': 'HeberZabdiel',
#    'display_login': 'HeberZabdiel',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/HeberZabdiel',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/42967728?'},
#   'repo': {'id': 300491479,
#    'name': 'HeberZabdiel/farmacias_gi',
#    'url': 'https://api.github.com/repos/HeberZabdiel/farmacias_gi'},
#   'payload': {'push_id': 7040328668,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'fa9052179e1fe0f594e73ebde561506d2022693e',
#    'before': '2d15fd0498644676568b236aae65a9e1e5ac57fb',
#    'commits': [{'sha': 'fa9052179e1fe0f594e73ebde561506d2022693e',
#      'author': {'email': 'hzhm1997@gmail.com', 'name': 'HeberZabdiel'},
#      'message': 'actualizacion Venta/index.blade.php',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/HeberZabdiel/farmacias_gi/commits/fa9052179e1fe0f594e73ebde561506d2022693e'}]},
#   'public': True,
#   'created_at': '2021-05-04T15:30:33Z'},
#  {'id': '16196834026',
#   'type': 'PushEvent',
#   'actor': {'id': 13786931,
#    'login': 'saagarjha',
#    'display_login': 'saagarjha',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/saagarjha',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13786931?'},
#   'repo': {'id': 135883999,
#    'name': 'saagarjha/binutils-gdb',
#    'url': 'https://api.github.com/repos/saagarjha/binutils-gdb'},
#   'payload': {'push_id': 7040328651,
#    'size': 1,
#    'distinct_size': 0,
#    'ref': 'refs/heads/master',
#    'head': '858c8f2c1b900258c44cebe2798ca0271100a33d',
#    'before': 'bd6d8601f304d03ecdebe1b1a7d48666845a91aa',
#    'commits': [{'sha': '858c8f2c1b900258c44cebe2798ca0271100a33d',
#      'author': {'email': 'simon.marchi@efficios.com', 'name': 'Simon Marchi'},
#      'message': 'gdb/testsuite: adjust gdb.python/flexible-array-member.exp expected pattern\n\nThe `Type.range ()` tests in gdb.python/flexible-array-member.exp pass\nwhen the test is compiled with gcc 9 or later, but not with gcc 8 or\nearlier:\n\n    $ make check TESTS="gdb.python/flexible-array-member.exp" RUNTESTFLAGS="CC_FOR_TARGET=\'gcc-8\'"\n\n    python print(zs[\'items\'].type.range())^M\n    (0, 0)^M\n    (gdb) FAIL: gdb.python/flexible-array-member.exp: python print(zs[\'items\'].type.range())\n    python print(zso[\'items\'].type.range())^M\n    (0, 0)^M\n    (gdb) FAIL: gdb.python/flexible-array-member.exp: python print(zso[\'items\'].type.range())\n\nThe value that we get for the upper bound of a flexible array member\ndeclared with a "0" size is 0 with gcc <= 8 and is -1 for gcc >= 9.\nThis is due to different debug info.  For this member, gcc 8 does:\n\n    0x000000d5:   DW_TAG_array_type\n                    DW_AT_type [DW_FORM_ref4]       (0x00000034 "int")\n                    DW_AT_sibling [DW_FORM_ref4]    (0x000000e4)\n\n    0x000000de:     DW_TAG_subrange_type\n                      DW_AT_type [DW_FORM_ref4]     (0x0000002d "long unsigned int")\n\nFor the same type, gcc 9 does:\n\n    0x000000d5:   DW_TAG_array_type\n                    DW_AT_type [DW_FORM_ref4]       (0x00000034 "int")\n                    DW_AT_sibling [DW_FORM_ref4]    (0x000000e5)\n\n    0x000000de:     DW_TAG_subrange_type\n                      DW_AT_type [DW_FORM_ref4]     (0x0000002d "long unsigned int")\n                      DW_AT_count [DW_FORM_data1]   (0x00)\n\nIdeally, GDB would present a consistent and documented value for an\narray member declared with size 0, regardless of how the debug info\nlooks like.  But for now, just change the test to accept the two\nvalues, to get rid of the failure and make the test in sync\n\nI also realized (by looking at the py-type.exp test) that calling the\nfields method on an array type yields one field representing the "index"\nof the array.  The type of that field is of type range\n(gdb.TYPE_CODE_RANGE).  When calling `.range()` on that range type, it\nyields the same range tuple as when calling `.range()` on the array type\nitself.  For completeness, add some tests to access the range tuple\nthrough that range type as well.\n\ngdb/testsuite/ChangeLog:\n\n\t* gdb.python/flexible-array-member.exp: Adjust expected range\n\tvalue for member declared with 0 size.  Test accessing range\n\ttuple through range type.\n\nChange-Id: Ie4e06d99fe9315527f04577888f48284d649ca4c',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/saagarjha/binutils-gdb/commits/858c8f2c1b900258c44cebe2798ca0271100a33d'}]},
#   'public': True,
#   'created_at': '2021-05-04T15:30:33Z'},
#  {'id': '16196834050',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 2445415,
#    'login': 'Ilyes512',
#    'display_login': 'Ilyes512',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Ilyes512',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2445415?'},
#   'repo': {'id': 4387220,
#    'name': 'beberlei/assert',
#    'url': 'https://api.github.com/repos/beberlei/assert'},
#   'payload': {'action': 'opened',
#    'number': 315,
#    'pull_request': {'url': 'https://api.github.com/repos/beberlei/assert/pulls/315',
#     'id': 629895516,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NjI5ODk1NTE2',
#     'html_url': 'https://github.com/beberlei/assert/pull/315',
#     'diff_url': 'https://github.com/beberlei/assert/pull/315.diff',
#     'patch_url': 'https://github.com/beberlei/assert/pull/315.patch',
#     'issue_url': 'https://api.github.com/repos/beberlei/assert/issues/315',
#     'number': 315,
#     'state': 'open',
#     'locked': False,
#     'title': 'Add more specific (static) return type to docblock',
#     'user': {'login': 'Ilyes512',
#      'id': 2445415,
#      'node_id': 'MDQ6VXNlcjI0NDU0MTU=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/2445415?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Ilyes512',
#      'html_url': 'https://github.com/Ilyes512',
#      'followers_url': 'https://api.github.com/users/Ilyes512/followers',
#      'following_url': 'https://api.github.com/users/Ilyes512/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Ilyes512/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Ilyes512/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Ilyes512/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Ilyes512/orgs',
#      'repos_url': 'https://api.github.com/users/Ilyes512/repos',
#      'events_url': 'https://api.github.com/users/Ilyes512/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Ilyes512/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'I have an exception that extends `\\Assert\\LazyAssertionException` and currently [psalm](https://psalm.dev/) is reporting 2 error related to the return type: ` MoreSpecificReturnType` and `LessSpecificReturnStatement`.',
#     'created_at': '2021-05-04T15:30:32Z',
#     'updated_at': '2021-05-04T15:30:32Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/beberlei/assert/pulls/315/commits',
#     'review_comments_url': 'https://api.github.com/repos/beberlei/assert/pulls/315/comments',
#     'review_comment_url': 'https://api.github.com/repos/beberlei/assert/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/beberlei/assert/issues/315/comments',
#     'statuses_url': 'https://api.github.com/repos/beberlei/assert/statuses/89afb76ecc6cf17cb650c6c8db942db6c8ec8d46',
#     'head': {'label': 'Ilyes512:master',
#      'ref': 'master',
#      'sha': '89afb76ecc6cf17cb650c6c8db942db6c8ec8d46',
#      'user': {'login': 'Ilyes512',
#       'id': 2445415,
#       'node_id': 'MDQ6VXNlcjI0NDU0MTU=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/2445415?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Ilyes512',
#       'html_url': 'https://github.com/Ilyes512',
#       'followers_url': 'https://api.github.com/users/Ilyes512/followers',
#       'following_url': 'https://api.github.com/users/Ilyes512/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Ilyes512/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Ilyes512/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Ilyes512/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Ilyes512/orgs',
#       'repos_url': 'https://api.github.com/users/Ilyes512/repos',
#       'events_url': 'https://api.github.com/users/Ilyes512/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Ilyes512/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 364300546,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzNjQzMDA1NDY=',
#       'name': 'assert',
#       'full_name': 'Ilyes512/assert',
#       'private': False,
#       'owner': {'login': 'Ilyes512',
#        'id': 2445415,
#        'node_id': 'MDQ6VXNlcjI0NDU0MTU=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/2445415?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Ilyes512',
#        'html_url': 'https://github.com/Ilyes512',
#        'followers_url': 'https://api.github.com/users/Ilyes512/followers',
#        'following_url': 'https://api.github.com/users/Ilyes512/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Ilyes512/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Ilyes512/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Ilyes512/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Ilyes512/orgs',
#        'repos_url': 'https://api.github.com/users/Ilyes512/repos',
#        'events_url': 'https://api.github.com/users/Ilyes512/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Ilyes512/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/Ilyes512/assert',
#       'description': 'Thin assertion library for use in libraries and business-model',
#       'fork': True,
#       'url': 'https://api.github.com/repos/Ilyes512/assert',
#       'forks_url': 'https://api.github.com/repos/Ilyes512/assert/forks',
#       'keys_url': 'https://api.github.com/repos/Ilyes512/assert/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Ilyes512/assert/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Ilyes512/assert/teams',
#       'hooks_url': 'https://api.github.com/repos/Ilyes512/assert/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Ilyes512/assert/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Ilyes512/assert/events',
#       'assignees_url': 'https://api.github.com/repos/Ilyes512/assert/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Ilyes512/assert/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Ilyes512/assert/tags',
#       'blobs_url': 'https://api.github.com/repos/Ilyes512/assert/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Ilyes512/assert/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Ilyes512/assert/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Ilyes512/assert/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Ilyes512/assert/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Ilyes512/assert/languages',
#       'stargazers_url': 'https://api.github.com/repos/Ilyes512/assert/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Ilyes512/assert/contributors',
# ...
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 72495579,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk3MjQ5NTU3OQ==',
#       'name': 'gitea',
#       'full_name': 'go-gitea/gitea',
#       'private': False,
#       'owner': {'login': 'go-gitea',
#        'id': 12724356,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjEyNzI0MzU2',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/12724356?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/go-gitea',
#        'html_url': 'https://github.com/go-gitea',
#        'followers_url': 'https://api.github.com/users/go-gitea/followers',
#        'following_url': 'https://api.github.com/users/go-gitea/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/go-gitea/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/go-gitea/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/go-gitea/subscriptions',
#        'organizations_url': 'https://api.github.com/users/go-gitea/orgs',
#        'repos_url': 'https://api.github.com/users/go-gitea/repos',
#        'events_url': 'https://api.github.com/users/go-gitea/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/go-gitea/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/go-gitea/gitea',
#       'description': 'Git with a cup of tea, painless self-hosted git service',
#       'fork': False,
#       'url': 'https://api.github.com/repos/go-gitea/gitea',
#       'forks_url': 'https://api.github.com/repos/go-gitea/gitea/forks',
#       'keys_url': 'https://api.github.com/repos/go-gitea/gitea/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/go-gitea/gitea/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/go-gitea/gitea/teams',
#       'hooks_url': 'https://api.github.com/repos/go-gitea/gitea/hooks',
#       'issue_events_url': 'https://api.github.com/repos/go-gitea/gitea/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/go-gitea/gitea/events',
#       'assignees_url': 'https://api.github.com/repos/go-gitea/gitea/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/go-gitea/gitea/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/go-gitea/gitea/tags',
#       'blobs_url': 'https://api.github.com/repos/go-gitea/gitea/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/go-gitea/gitea/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/go-gitea/gitea/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/go-gitea/gitea/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/go-gitea/gitea/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/go-gitea/gitea/languages',
#       'stargazers_url': 'https://api.github.com/repos/go-gitea/gitea/stargazers',
#       'contributors_url': 'https://api.github.com/repos/go-gitea/gitea/contributors',
#       'subscribers_url': 'https://api.github.com/repos/go-gitea/gitea/subscribers',
#       'subscription_url': 'https://api.github.com/repos/go-gitea/gitea/subscription',
#       'commits_url': 'https://api.github.com/repos/go-gitea/gitea/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/go-gitea/gitea/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/go-gitea/gitea/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/go-gitea/gitea/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/go-gitea/gitea/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/go-gitea/gitea/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/go-gitea/gitea/merges',
#       'archive_url': 'https://api.github.com/repos/go-gitea/gitea/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/go-gitea/gitea/downloads',
#       'issues_url': 'https://api.github.com/repos/go-gitea/gitea/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/go-gitea/gitea/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/go-gitea/gitea/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/go-gitea/gitea/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/go-gitea/gitea/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/go-gitea/gitea/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/go-gitea/gitea/deployments',
#       'created_at': '2016-11-01T02:13:26Z',
#       'updated_at': '2021-05-04T14:54:58Z',
#       'pushed_at': '2021-05-04T15:20:51Z',
#       'git_url': 'git://github.com/go-gitea/gitea.git',
#       'ssh_url': 'git@github.com:go-gitea/gitea.git',
#       'clone_url': 'https://github.com/go-gitea/gitea.git',
#       'svn_url': 'https://github.com/go-gitea/gitea',
#       'homepage': 'https://gitea.io',
#       'size': 200475,
#       'stargazers_count': 24652,
#       'watchers_count': 24652,
#       'language': 'Go',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 3011,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1743,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 3011,
#       'open_issues': 1743,
#       'watchers': 24652,
#       'default_branch': 'master'}},
#     'base': {'label': 'bai:master',
#      'ref': 'master',
#      'sha': 'ed393779004335a0afcca0dfac48937db41fabd6',
#      'user': {'login': 'bai',
#       'id': 17348,
#       'node_id': 'MDQ6VXNlcjE3MzQ4',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/17348?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/bai',
#       'html_url': 'https://github.com/bai',
#       'followers_url': 'https://api.github.com/users/bai/followers',
#       'following_url': 'https://api.github.com/users/bai/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/bai/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/bai/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/bai/subscriptions',
#       'organizations_url': 'https://api.github.com/users/bai/orgs',
#       'repos_url': 'https://api.github.com/users/bai/repos',
#       'events_url': 'https://api.github.com/users/bai/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/bai/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 172119940,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxNzIxMTk5NDA=',
#       'name': 'gitea',
#       'full_name': 'bai/gitea',
#       'private': False,
#       'owner': {'login': 'bai',
#        'id': 17348,
#        'node_id': 'MDQ6VXNlcjE3MzQ4',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/17348?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/bai',
#        'html_url': 'https://github.com/bai',
#        'followers_url': 'https://api.github.com/users/bai/followers',
#        'following_url': 'https://api.github.com/users/bai/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/bai/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/bai/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/bai/subscriptions',
#        'organizations_url': 'https://api.github.com/users/bai/orgs',
#        'repos_url': 'https://api.github.com/users/bai/repos',
#        'events_url': 'https://api.github.com/users/bai/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/bai/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/bai/gitea',
#       'description': 'Git with a cup of tea, painless self-hosted git service',
#       'fork': True,
#       'url': 'https://api.github.com/repos/bai/gitea',
#       'forks_url': 'https://api.github.com/repos/bai/gitea/forks',
#       'keys_url': 'https://api.github.com/repos/bai/gitea/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/bai/gitea/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/bai/gitea/teams',
#       'hooks_url': 'https://api.github.com/repos/bai/gitea/hooks',
#       'issue_events_url': 'https://api.github.com/repos/bai/gitea/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/bai/gitea/events',
#       'assignees_url': 'https://api.github.com/repos/bai/gitea/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/bai/gitea/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/bai/gitea/tags',
#       'blobs_url': 'https://api.github.com/repos/bai/gitea/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/bai/gitea/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/bai/gitea/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/bai/gitea/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/bai/gitea/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/bai/gitea/languages',
#       'stargazers_url': 'https://api.github.com/repos/bai/gitea/stargazers',
#       'contributors_url': 'https://api.github.com/repos/bai/gitea/contributors',
#       'subscribers_url': 'https://api.github.com/repos/bai/gitea/subscribers',
#       'subscription_url': 'https://api.github.com/repos/bai/gitea/subscription',
#       'commits_url': 'https://api.github.com/repos/bai/gitea/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/bai/gitea/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/bai/gitea/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/bai/gitea/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/bai/gitea/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/bai/gitea/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/bai/gitea/merges',
#       'archive_url': 'https://api.github.com/repos/bai/gitea/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/bai/gitea/downloads',
#       'issues_url': 'https://api.github.com/repos/bai/gitea/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/bai/gitea/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/bai/gitea/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/bai/gitea/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/bai/gitea/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/bai/gitea/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/bai/gitea/deployments',
#       'created_at': '2019-02-22T19:03:36Z',
#       'updated_at': '2021-05-04T03:30:32Z',
#       'pushed_at': '2021-05-04T15:30:30Z',
#       'git_url': 'git://github.com/bai/gitea.git',
#       'ssh_url': 'git@github.com:bai/gitea.git',
#       'clone_url': 'https://github.com/bai/gitea.git',
#       'svn_url': 'https://github.com/bai/gitea',
#       'homepage': 'https://gitea.io',
#       'size': 197663,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Go',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/bai/gitea/pulls/193'},
#      'html': {'href': 'https://github.com/bai/gitea/pull/193'},
#      'issue': {'href': 'https://api.github.com/repos/bai/gitea/issues/193'},
#      'comments': {'href': 'https://api.github.com/repos/bai/gitea/issues/193/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/bai/gitea/pulls/193/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/bai/gitea/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/bai/gitea/pulls/193/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/bai/gitea/statuses/21465a2ce361eeb2bff171a0b962dac771ab18d9'}},
#     'author_association': 'NONE',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'pull[bot]',
#      'id': 39814207,
#      'node_id': 'MDM6Qm90Mzk4MTQyMDc=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/12910?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/pull%5Bbot%5D',
#      'html_url': 'https://github.com/apps/pull',
#      'followers_url': 'https://api.github.com/users/pull%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/pull%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/pull%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/pull%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/pull%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/pull%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/pull%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/pull%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/pull%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 3,
#     'additions': 33,
#     'deletions': 17,
#     'changed_files': 5}},
#   'public': True,
#   'created_at': '2021-05-04T15:30:33Z'},
#  {'id': '16196833983',
#   'type': 'PushEvent',
#   'actor': {'id': 40320449,
#    'login': 'AmilaWeerasinghe',
#    'display_login': 'AmilaWeerasinghe',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AmilaWeerasinghe',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/40320449?'},
#   'repo': {'id': 360437002,
#    'name': 'AmilaWeerasinghe/dive-into-vue-js',
#    'url': 'https://api.github.com/repos/AmilaWeerasinghe/dive-into-vue-js'},
#   'payload': {'push_id': 7040328619,
#    'size': 3,
#    'distinct_size': 3,
#    'ref': 'refs/heads/master',
#    'head': '9c661c9d5955f602ac9d675a0941131d6c6fa3bf',
#    'before': 'de83e8402427e774883c7ed63f731ae10aa71c97',
#    'commits': [{'sha': '4d0cda98e13e586db1de6eb516fb561910ce957a',
#      'author': {'email': 'amilaweerasinghe677@gmail.com',
#       'name': 'AmilaWeerasinghe'},
#      'message': 'blockly static test',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/AmilaWeerasinghe/dive-into-vue-js/commits/4d0cda98e13e586db1de6eb516fb561910ce957a'},
#     {'sha': '15369fdf902d7353ff7bb5e75e4d4180d9fd9e72',
#      'author': {'email': 'amilaweerasinghe677@gmail.com',
#       'name': 'AmilaWeerasinghe'},
#      'message': 'custom block',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/AmilaWeerasinghe/dive-into-vue-js/commits/15369fdf902d7353ff7bb5e75e4d4180d9fd9e72'},
#     {'sha': '9c661c9d5955f602ac9d675a0941131d6c6fa3bf',
#      'author': {'email': 'amilaweerasinghe677@gmail.com',
#       'name': 'AmilaWeerasinghe'},
#      'message': 'custom blocks and integrating',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/AmilaWeerasinghe/dive-into-vue-js/commits/9c661c9d5955f602ac9d675a0941131d6c6fa3bf'}]},
#   'public': True,
#   'created_at': '2021-05-04T15:30:33Z'}]
